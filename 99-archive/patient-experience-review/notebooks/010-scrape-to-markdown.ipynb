# %% [markdown]
# # Scrape the websites
#
# The first step is to spider crawl the top level page and grab all pages and put them into a markdown file.

# %%
import os
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup

DATA_FOLDER = '../data/raw'

def ensure_directory(folder_name):
    full_path = os.path.join(DATA_FOLDER, folder_name)
    if not os.path.exists(full_path):
        os.makedirs(full_path)
    return full_path

def get_internal_links(site):
    root_url = site["root_url"]
    folder_name = site.get("folder_name") or urlparse(root_url).netloc
    folder_path = ensure_directory(folder_name)

    internal_links = set()
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    try:
        response = requests.get(root_url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, "html.parser")

        for link in soup.find_all("a", href=True):
            href = link["href"]
            joined_url = urljoin(root_url, href)
            parsed_url = urlparse(joined_url)

            if parsed_url.netloc == urlparse(root_url).netloc:
                internal_links.add(joined_url)

    except requests.RequestException as e:
        print(f"An error occurred: {e}")

    with open(os.path.join(folder_path, "internal_links.txt"), "w") as file:
        for link in internal_links:
            file.write(f"{link}\n")

    return list(internal_links)

def scrape_to_markdown(site, urls):
    folder_name = site.get("folder_name") or urlparse(site["root_url"]).netloc
    folder_path = ensure_directory(folder_name)
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    for url in urls:
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")
            title = soup.find("title").text.strip()
            paragraphs = soup.find_all("p")
            content = "\n".join(p.get_text().strip() for p in paragraphs)

            markdown_content = f"# {title}\n\n{content}"
            output_file_name = url.rstrip('/').split('/')[-1] + ".md"
            output_file = os.path.join(folder_path, output_file_name)

            with open(output_file, "w") as file:
                file.write(markdown_content)
            print(f"Markdown file '{output_file}' created successfully.")
        except Exception as e:
            print(f"An error occurred for URL '{url}': {e}")

def main(sites=None):
    if sites is None:
        sites = [
            {"root_url": "https://pcare.com/"},
            {"root_url": "https://www.hci-tv.com/"},
            {"root_url": "https://www.sonifi.com/"},
            {"root_url": "https://www.evideon.com/"},
            # Add more sites as needed
        ]
    for site in sites:
        internal_links = get_internal_links(site)
        scrape_to_markdown(site, internal_links)

if __name__ == "__main__":
    main()
# Out:
# Markdown file '../data/raw/pcare.com/room-of-the-future.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare.com.md' created successfully.
# Markdown file '../data/raw/pcare.com/sitemap.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare.com.md' created successfully.
# Markdown file '../data/raw/pcare.com/ips.md' created successfully.
# Markdown file '../data/raw/pcare.com/room-connect.md' created successfully.
# Markdown file '../data/raw/pcare.com/digital-signage-and-wayfinding.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare-interactive-patient-care-system-ips-demo-video-series.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare-cloud.md' created successfully.
# Markdown file '../data/raw/pcare.com/partners.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare-mobile.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare-achieves-hitrust-implemented-1-year-i1-certification-to-manage-data-protection-and-mitigate-cybersecurity-threats.md' created successfully.
# Markdown file '../data/raw/pcare.com/leadership.md' created successfully.
# Markdown file '../data/raw/pcare.com/truthpoint.md' created successfully.
# Markdown file '../data/raw/pcare.com/nurse-retention.md' created successfully.
# Markdown file '../data/raw/pcare.com/operational-efficiency.md' created successfully.
# Markdown file '../data/raw/pcare.com/ips-platform.md' created successfully.
# Markdown file '../data/raw/pcare.com/truthpoint-rounds.md' created successfully.
# Markdown file '../data/raw/pcare.com/digital-whiteboard.md' created successfully.
# Markdown file '../data/raw/pcare.com/staff-empowerment.md' created successfully.
# Markdown file '../data/raw/pcare.com/audiovisual-services.md' created successfully.
# Markdown file '../data/raw/pcare.com/service-terms.md' created successfully.
# Markdown file '../data/raw/pcare.com/resources.md' created successfully.
# Markdown file '../data/raw/pcare.com/platform.md' created successfully.
# Markdown file '../data/raw/pcare.com/about-us.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare-videoconnect.md' created successfully.
# Markdown file '../data/raw/pcare.com/contact.md' created successfully.
# Markdown file '../data/raw/pcare.com/technology-solutions.md' created successfully.
# Markdown file '../data/raw/pcare.com/hospital-of-the-future.md' created successfully.
# Markdown file '../data/raw/pcare.com/ips.md' created successfully.
# Markdown file '../data/raw/pcare.com/careers.md' created successfully.
# Markdown file '../data/raw/pcare.com/pediatric-solutions.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare-practice.md' created successfully.
# Markdown file '../data/raw/pcare.com/pcare-ambulatory-2.md' created successfully.
# Markdown file '../data/raw/pcare.com/television-services.md' created successfully.
# Markdown file '../data/raw/pcare.com/infusion.md' created successfully.
# Markdown file '../data/raw/pcare.com/patient-engagement.md' created successfully.
# Markdown file '../data/raw/pcare.com/privacy-policy.md' created successfully.
# Markdown file '../data/raw/pcare.com/solutions.md' created successfully.
# Markdown file '../data/raw/pcare.com/digital-transformation-interactive-checklist.md' created successfully.
# Markdown file '../data/raw/pcare.com/glp-1-medications-and-4-patient-engagement-best-practices.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/blog.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/labor-and-delivery-whiteboard?hsLang=en.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/get-a-quote.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/hci-release-labor-and-deliver-interactive-digital-whiteboard?hsLang=en.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/integrations?hsLang=en.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/interactive-unit-status-boards.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/hci-integrates-with-samsung?hsLang=en.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/patient-tv.md' created successfully.
# An error occurred for URL 'https://www.hci-tv.com/act3?hsLang=en': 404 Client Error: Not Found for url: https://www.hci-tv.com/act3?hsLang=en
# Markdown file '../data/raw/www.hci-tv.com/?hsLang=en.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/www.hci-tv.com.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/interactive-door-signs.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/contact-us.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/electronic-sound-partners-with-hci?hsLang=en.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/about-us.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/interactive-digital-whiteboards.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/request-an-rma.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/partners?hsLang=en.md' created successfully.
# Markdown file '../data/raw/www.hci-tv.com/request-a-demo.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/streaming.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/entertainment.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/copyright.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/smart-room-integrations.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/interactive-solutions.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/about-us.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/#tabPanel1-c2df5d4bf55d83bb64626af43e8bbb02.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/transparency.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/marriott.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/legal.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/#tabPanel2-c2df5d4bf55d83bb64626af43e8bbb02.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/internet-services.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/independents.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/resorts-world-las-vegas.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/customer-resources.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/privacy.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/wyndham.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/advertising-content.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/choice.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/brands.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/news.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/ott-streaming.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/casinos.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/leadership.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/support.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/hyatt.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/brands.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/owners-managers.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/resources.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/#mainContent.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/technology.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/amp-press-release.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/resorts.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/terms-of-service.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/#tabPanel0-c2df5d4bf55d83bb64626af43e8bbb02.md' created successfully.
# Markdown file '../data/raw/www.sonifi.com/www.sonifi.com.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/insight.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/vibe-health.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/about-us#careers.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/#workflow-solutions.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/www.evideon.com.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/through-the-lens-of-a-caregiver-how-health-systems-can-support-with-technology.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/#clinical-solutions.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/technology.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/aware.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/hello.md' created successfully.
# An error occurred for URL 'http://www.evideon.com/sitemap.xml': 'NoneType' object has no attribute 'text'
# Markdown file '../data/raw/www.evideon.com/webinars.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/#veteran-solutions.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/faq.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/companion.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/about-us#security.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/about-us.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/clinical-solutions.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/results.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/about-us#about-us.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/about-us#news.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/#patient-education.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/engage.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/innovation-to-accelerate-excellence-on-the-magnet-journey.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/#technology.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/about-us#works-with.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/events.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/patient-education.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/healthcareit-news-features-valley-health-system-cio-eric-carey-on-vibe-health-powered-smart-hospital.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/veteran-solutions.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/#patient-experience.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/features.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/banner.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/3-keys-to-improving-the-pediatric-patient-experience-comfort-communication-and-education.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/about-us#contact.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/blog.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/patient-experience.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/health-data-management-why-tampa-general-hospital-placed-its-bets-on-smart-room-technology.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/healthcare-business-today-dear-healthcare-system-a-caregivers-reflections-from-raising-a-child-with-a-rare-condition.md' created successfully.
# Markdown file '../data/raw/www.evideon.com/workflow-solutions.md' created successfully.
