# %%
import pandas as pd

# %%
path_banh = '../data/processed/banh.csv'
banh_df = pd.read_csv(path_banh)
banh_df['Units'] = pd.to_numeric(banh_df['Units'].astype(str).str.replace(r'\D', ''), errors='coerce')
# banh_df['Charge'] = banh_df['Charge'].str.replace(r'[$,]', '').astype(float)
banh_df.head(5)
# Out:
#   physician Procedure Code       Procedure Description  Units      Charge
# 0      banh          10060    DRAINAGE OF SKIN ABSCESS   11.0   $3,771.40
# 1      banh          10120         REMOVE FOREIGN BODY    9.0   $3,720.60
# 2      banh          10140  DRAINAGE OF HEMATOMA/FLUID    3.0   $1,399.11
# 3      banh          11042  DEB SUBQ TISSUE 20 SQ CM/<   36.0  $12,862.20
# 4      banh          11055            TRIM SKIN LESION   49.0   $9,962.57

# %%
path_gittens = '../data/processed/gittens.csv'
gittens_df = pd.read_csv(path_gittens)
gittens_df['Units'] = pd.to_numeric(gittens_df['Units'].astype(str).str.replace(r'\D', ''), errors='coerce')
# gittens_df['Charge'] = gittens_df['Charge'].str.replace(r'[$,]', '').astype(float)
gittens_df.head(5)
# Out:
#   physician Procedure Code       Procedure Description  Units      Charge
# 0   gittens          10021               FNA W/O IMAGE    1.0     $285.70
# 1   gittens          10060    DRAINAGE OF SKIN ABSCESS   20.0   $7,104.21
# 2   gittens          10140  DRAINAGE OF HEMATOMA/FLUID    3.0   $1,478.98
# 3   gittens          11042  DEB SUBQ TISSUE 20 SQ CM/<   43.0  $15,985.55
# 4   gittens          11043  DEB MUSC/FASCIA 20 SQ CM/<    1.0     $644.03

# %%
path_haspel = '../data/processed/haspel.csv'
haspel_df = pd.read_csv(path_haspel)
haspel_df['Units'] = pd.to_numeric(haspel_df['Units'].astype(str).str.replace(r'\D', ''), errors='coerce')
# haspel_df['Charge'] = haspel_df['Charge'].str.replace(r'[$,]', '').astype(float)
haspel_df.head(5)
# Out:
#   physician Procedure Code       Procedure Description  Units      Charge
# 0    haspel          10060    DRAINAGE OF SKIN ABSCESS     29  $10,384.26
# 1    haspel          10120         REMOVE FOREIGN BODY      2     $888.66
# 2    haspel          11042  DEB SUBQ TISSUE 20 SQ CM/<     16   $5,991.80
# 3    haspel          11043  DEB MUSC/FASCIA 20 SQ CM/<      3   $1,932.09
# 4    haspel          11044         DEB BONE 20 SQ CM/<      3   $2,593.50

# %%
path_manheim= '../data/processed/manheim.csv'
manheim_df = pd.read_csv(path_manheim)
manheim_df['Units'] = pd.to_numeric(manheim_df['Units'].astype(str).str.replace(r'\D', ''), errors='coerce')
# manheim_df['Charge'] = manheim_df['Charge'].str.replace(r'[$,]', '').astype(float)
manheim_df.head(5)
# Out:
#   physician Procedure Code        Procedure Description  Units     Charge
# 0   manheim          10060                          I&D      7  $2,529.41
# 1   manheim          10061     DRAINAGE OF SKIN ABSCESS      2  $1,234.30
# 2   manheim          10120          REMOVE FOREIGN BODY      3  $1,287.75
# 3   manheim          10140   DRAINAGE OF HEMATOMA/FLUID      6  $2,861.28
# 4   manheim          10160  PUNCTURE DRAINAGE OF LESION      6  $2,223.20

# %%
path_osemene = '../data/processed/osemene.csv'
osemene_df = pd.read_csv(path_osemene)
osemene_df['Units'] = pd.to_numeric(osemene_df['Units'].astype(str).str.replace(r'\D', ''), errors='coerce')
# osemene_df['Charge'] = osemene_df['Charge'].str.replace(r'[$,]', '').astype(float)
osemene_df.head(5)
# Out:
#   physician Procedure Code       Procedure Description  Units      Charge
# 0   Osemene          10021               FNA W/O IMAGE      1     $285.70
# 1   Osemene          10060    DRAINAGE OF SKIN ABSCESS     20   $7,104.21
# 2   Osemene          10140  DRAINAGE OF HEMATOMA/FLUID      3   $1,478.98
# 3   Osemene          11042  DEB SUBQ TISSUE 20 SQ CM/<     43  $15,985.55
# 4   Osemene          11043  DEB MUSC/FASCIA 20 SQ CM/<      1     $644.03

# %%
path_perel = '../data/processed/perel.csv'
perel_df = pd.read_csv(path_perel)
perel_df['Units'] = pd.to_numeric(perel_df['Units'].astype(str).str.replace(r'\D', ''), errors='coerce')
# perel_df['Charge'] = perel_df['Charge'].str.replace(r'[$,]', '').astype(float)
perel_df.head(5)
# Out:
#   physician Procedure Code        Procedure Description  Units     Charge
# 0     perel          10060     DRAINAGE OF SKIN ABSCESS      5  $1,800.51
# 1     perel          10120          REMOVE FOREIGN BODY      2    $873.58
# 2     perel          10121          REMOVE FOREIGN BODY      1    $741.93
# 3     perel          10160  PUNCTURE DRAINAGE OF LESION      1    $379.20
# 4     perel          11042   DEB SUBQ TISSUE 20 SQ CM/<     25  $7,500.00

# %%
path_phan = '../data/processed/phan.csv'
phan_df = pd.read_csv(path_phan)
phan_df['Units'] = pd.to_numeric(phan_df['Units'].astype(str).str.replace(r'\D', ''), errors='coerce')
# phan_df['Charge'] = phan_df['Charge'].str.replace(r'[$,]', '').astype(float)
phan_df.head(5)
# Out:
#   physician Procedure Code     Procedure Description  Units     Charge
# 0      phan          11055          TRIM SKIN LESION      2    $437.40
# 1      phan          11056  TRIM SKIN LESIONS 2 TO 4     13  $3,146.31
# 2      phan          11719              TRIM NAIL(S)     17    $674.61
# 3      phan          11720  NAIL DEBRIDEMENT/CALLOUS      5    $465.20
# 4      phan          11721  NAIL DEBRIDEMENT/CALLOUS     12  $1,500.06

# %%
path_yeung = '../data/processed/yeung.csv'
yeung_df = pd.read_csv(path_yeung)
yeung_df['Units'] = pd.to_numeric(yeung_df['Units'].astype(str).str.replace(r'\D', ''), errors='coerce')
# yeung_df['Charge'] = yeung_df['Charge'].str.replace(r'[$,]', '').astype(float)
yeung_df.head(5)
# Out:
#   physician Procedure Code     Procedure Description  Units     Charge
# 0     yeung          10060  DRAINAGE OF SKIN ABSCESS    6.0  $2,286.70
# 1     yeung          10120       REMOVE FOREIGN BODY    3.0  $1,287.75
# 2     yeung          11055          TRIM SKIN LESION    1.0    $218.70
# 3     yeung          11720  NAIL DEBRIDEMENT/CALLOUS    1.0     $94.60
# 4     yeung          11721   NAIL DEBRIDEMENT (6-10)    2.0    $245.96

# %%
# Merge the two dataframes on 'Procedure Code' to compare the units
comparison_df = pd.merge(banh_df, gittens_df, on='Procedure Code', how='outer', suffixes=('_banh', '_gittens'))

# Select relevant columns for the comparison
comparison_df = comparison_df[['Procedure Code', 'Units_banh', 'Units_gittens']]

# Fill NaN values with 0 for easier comparison
comparison_df.fillna(0, inplace=True)

# Calculate the difference in units for each procedure code
comparison_df['Difference'] = comparison_df['Units_banh'] - comparison_df['Units_gittens']

# Convert the 'Units' columns to numeric after cleaning any non-numeric characters
comparison_df['Units_banh'] = pd.to_numeric(comparison_df['Units_banh'].astype(str).str.replace(r'\D', ''), errors='coerce')
comparison_df['Units_gittens'] = pd.to_numeric(comparison_df['Units_gittens'].astype(str).str.replace(r'\D', ''), errors='coerce')

# Calculate the difference in units for each procedure code
comparison_df['Difference'] = comparison_df['Units_banh'] - comparison_df['Units_gittens']

comparison_df
# Out:
#     Procedure Code  Units_banh  Units_gittens  Difference
# 0            10060        11.0           20.0        -9.0
# 1            10120         9.0            0.0         9.0
# 2            10140         3.0            3.0         0.0
# 3            11042        36.0           43.0        -7.0
# 4            11055        49.0          101.0       -52.0
# ..             ...         ...            ...         ...
# 96           A6456         0.0            1.0        -1.0
# 97           J0702         0.0           91.0       -91.0
# 98           L3649         0.0           14.0       -14.0
# 99           99204         0.0            3.0        -3.0
# 100          99214         0.0            4.0        -4.0
#
# [101 rows x 4 columns]

# %%
# Select relevant columns for display after formatting
banh_display = banh_df[['Procedure Code', 'Procedure Description', 'Units', 'Charge']]
gittens_display = gittens_df[['Procedure Code', 'Procedure Description', 'Units', 'Charge']]

# Display the first few rows of each dataframe with the selected columns
banh_display_head = banh_display.head()
gittens_display_head = gittens_display.head()

banh_display_head, gittens_display_head
# Out:
# (  Procedure Code       Procedure Description  Units      Charge
#  0          10060    DRAINAGE OF SKIN ABSCESS   11.0   $3,771.40
#  1          10120         REMOVE FOREIGN BODY    9.0   $3,720.60
#  2          10140  DRAINAGE OF HEMATOMA/FLUID    3.0   $1,399.11
#  3          11042  DEB SUBQ TISSUE 20 SQ CM/<   36.0  $12,862.20
#  4          11055            TRIM SKIN LESION   49.0   $9,962.57,
#    Procedure Code       Procedure Description  Units      Charge
#  0          10021               FNA W/O IMAGE    1.0     $285.70
#  1          10060    DRAINAGE OF SKIN ABSCESS   20.0   $7,104.21
#  2          10140  DRAINAGE OF HEMATOMA/FLUID    3.0   $1,478.98
#  3          11042  DEB SUBQ TISSUE 20 SQ CM/<   43.0  $15,985.55
#  4          11043  DEB MUSC/FASCIA 20 SQ CM/<    1.0     $644.03)

# %%
# Merge the dataframes on both 'Procedure Code' and 'Procedure Description' for accurate comparison
comparison_df = pd.merge(banh_df, gittens_df, on=['Procedure Code', 'Procedure Description'], how='outer', suffixes=('_banh', '_gittens'))

# Select the relevant columns for the comparison
comparison_df = comparison_df[['Procedure Code', 'Procedure Description', 'Units_banh', 'Units_gittens']]

# Fill NaN values with 0 for easier comparison
comparison_df.fillna(0, inplace=True)

# Calculate the difference in units for each procedure code and description
comparison_df['Difference'] = comparison_df['Units_banh'] - comparison_df['Units_gittens']

comparison_df.head()
# Out:
#   Procedure Code       Procedure Description  Units_banh  Units_gittens  \
# 0          10060    DRAINAGE OF SKIN ABSCESS        11.0           20.0
# 1          10120         REMOVE FOREIGN BODY         9.0            0.0
# 2          10140  DRAINAGE OF HEMATOMA/FLUID         3.0            3.0
# 3          11042  DEB SUBQ TISSUE 20 SQ CM/<        36.0           43.0
# 4          11055            TRIM SKIN LESION        49.0          101.0
#
#    Difference
# 0        -9.0
# 1         9.0
# 2         0.0
# 3        -7.0
# 4       -52.0

# %%
# Adjust pandas display settings to show the entire dataframe
pd.set_option('display.max_rows', None)


# Display the entire comparison dataframe
comparison_df
# Out:
#     Procedure Code                              Procedure Description  \
# 0            10060                           DRAINAGE OF SKIN ABSCESS
# 1            10120                                REMOVE FOREIGN BODY
# 2            10140                         DRAINAGE OF HEMATOMA/FLUID
# 3            11042                         DEB SUBQ TISSUE 20 SQ CM/<
# 4            11055                                   TRIM SKIN LESION
# 5            11056                           TRIM SKIN LESIONS 2 TO 4
# 6            11057                           TRIM SKIN LESIONS OVER 4
# 7            11102
# 8            11104
# 9            11106
# 10           11420                        EXC H-F-NK-SP B9+MARG 0.5 <
# 11           11719                                  TRIMMING OF NAILS
# 12           11720                          NAIL DEBRIDEMENT/ CALLOUS
# 13           11721                           NAIL DEBRIDEMENT/CALLOUS
# ...

# %%
# Sort the comparison dataframe by the 'Difference' column in descending order
sorted_comparison_df = comparison_df.sort_values(by='Difference', ascending=False)

# Display the sorted dataframe
sorted_comparison_df
# Out:
#     Procedure Code                              Procedure Description  \
# 56           L3000                                   CUSTOM ORTHOTICS
# 13           11721                           NAIL DEBRIDEMENT/CALLOUS
# 65           S0395                              Impression casting ft
# 12           11720                          NAIL DEBRIDEMENT/ CALLOUS
# 35           29540                                          STRAPPING
# 46           J3301                         Triamcinolone acet inj NOS
# 40           A4580                            Cast supplies (plaster)
# 19           17110                            DESTRUCT B9 LESION 1-14
# 11           11719                                  TRIMMING OF NAILS
# 42           A5512                       Multi den insert direct form
# 22           20550                                         INJECTIONS
# 47           L1902                              A-60,PTTD,WEB,GAMEDAY
# ...
