# %%
import os
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain_openai import ChatOpenAI
from langchain import hub
from langchain.agents import create_openai_functions_agent
from langchain.agents import AgentExecutor
from langchain.globals import set_verbose, set_debug

def run_langchain_query(verbose=False, debug=False):
    # Set the verbose and debug modes as per the function arguments
    set_verbose(verbose)
    set_debug(debug)

    # Your existing code to set up and run the query
    prompt = hub.pull("hwchase17/openai-functions-agent")
    llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
    search = TavilySearchResults()
    tools = [search]
    agent = create_openai_functions_agent(llm, tools, prompt)
    agent_executor = AgentExecutor(agent=agent, tools=tools)

    # Execute the query
    return agent_executor.invoke({"input": "what is the weather in San Diego?"})

# %%
# Show verbose and debug output
response = run_langchain_query(verbose=True, debug=True)
print(response)
# Out:
# [chain/start] [chain:AgentExecutor] Entering Chain run with input:
# {
#   "input": "what is the weather in San Diego?"
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad> > chain:RunnableParallel<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad> > chain:RunnableParallel<agent_scratchpad> > chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad> > chain:RunnableParallel<agent_scratchpad> > chain:RunnableLambda] s] Exiting Chain run with output:
# {
#   "output": []
# }
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad> > chain:RunnableParallel<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "agent_scratchpad": []
# }
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad>] s] Exiting Chain run with output:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": [],
#   "agent_scratchpad": []
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "what is the weather in San Diego?",
#   "intermediate_steps": [],
#   "agent_scratchpad": []
# }
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:AgentExecutor > chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are a helpful assistant\nHuman: what is the weather in San Diego?"
#   ]
# }
# [llm/end] [chain:AgentExecutor > chain:RunnableSequence > llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "",
#         "generation_info": {
#           "finish_reason": "function_call"
#         },
#         "type": "ChatGenerationChunk",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessageChunk"
#           ],
#           "kwargs": {
#             "content": "",
#             "additional_kwargs": {
#               "function_call": {
#                 "arguments": "{\"query\":\"weather in San Diego\"}",
#                 "name": "tavily_search_results_json"
#               }
#             },
#             "response_metadata": {
#               "finish_reason": "function_call"
#             },
#             "type": "AIMessageChunk",
#             "id": "run-e99bedba-e768-4e5e-94e6-ed34bc4c7dd3",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# [outputs]
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# [tool/start] [chain:AgentExecutor > tool:tavily_search_results_json] Entering Tool run with input:
# "{'query': 'weather in San Diego'}"
# Error in ConsoleCallbackHandler.on_tool_end callback: AttributeError("'list' object has no attribute 'strip'")
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad> > chain:RunnableParallel<agent_scratchpad>] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad> > chain:RunnableParallel<agent_scratchpad> > chain:RunnableLambda] Entering Chain run with input:
# {
#   "input": ""
# }
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad> > chain:RunnableParallel<agent_scratchpad> > chain:RunnableLambda] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad> > chain:RunnableParallel<agent_scratchpad>] s] Exiting Chain run with output:
# [outputs]
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > chain:RunnableAssign<agent_scratchpad>] s] Exiting Chain run with output:
# [outputs]
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# [outputs]
# [llm/start] [chain:AgentExecutor > chain:RunnableSequence > llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are a helpful assistant\nHuman: what is the weather in San Diego?\nAI: {'arguments': '{\"query\":\"weather in San Diego\"}', 'name': 'tavily_search_results_json'}\nFunction: [{\"url\": \"https://www.weatherapi.com/\", \"content\": \"{'location': {'name': 'San Diego', 'region': 'California', 'country': 'United States of America', 'lat': 32.72, 'lon': -117.16, 'tz_id': 'America/Los_Angeles', 'localtime_epoch': 1718306169, 'localtime': '2024-06-13 12:16'}, 'current': {'last_updated_epoch': 1718305200, 'last_updated': '2024-06-13 12:00', 'temp_c': 20.6, 'temp_f': 69.1, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 10.5, 'wind_kph': 16.9, 'wind_degree': 290, 'wind_dir': 'WNW', 'pressure_mb': 1016.0, 'pressure_in': 30.01, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 68, 'cloud': 75, 'feelslike_c': 20.6, 'feelslike_f': 69.1, 'windchill_c': 20.9, 'windchill_f': 69.7, 'heatindex_c': 23.3, 'heatindex_f': 73.9, 'dewpoint_c': 13.5, 'dewpoint_f': 56.3, 'vis_km': 16.0, 'vis_miles': 9.0, 'uv': 6.0, 'gust_mph': 15.0, 'gust_kph': 24.1}}\"}, {\"url\": \"https://www.accuweather.com/en/us/san-diego/92101/weather-forecast/347628\", \"content\": \"San Diego, CA Weather Forecast, with current conditions, wind, air quality, and what to expect for the next 3 days.\"}, {\"url\": \"https://www.wunderground.com/hourly/us/ca/san-diego/92101/date/2024-06-13\", \"content\": \"Weather Underground provides local & long-range weather forecasts, weatherreports, maps & tropical weather conditions for the San Diego area. ... Thursday 06/13 Hourly for Tomorrow, Thu 06/13\"}, {\"url\": \"https://www.weather.gov/sgx/\", \"content\": \"Not much change near the coast with the mountains and deserts around 5 degrees warmer than Monday. Highs in San Diego County in the mid to upper 60s near the coast to the lower 80s for the far inland valleys, in Orange County in the mid to upper 60s near the coast to the upper 70s for far inland Orange County, in the 80s and lower 90s for the Inland Empire, in the mid 90s to 105 for the Apple ...\"}, {\"url\": \"https://www.timeanddate.com/weather/usa/san-diego/hourly\", \"content\": \"Hour-by-Hour Forecast for San Diego, California, USA. Weather Today Weather Hourly 14 Day Forecast Yesterday/Past Weather Climate (Averages) Currently: 61 °F. Overcast. (Weather station: San Diego - North Island, USA). See more current weather.\"}]"
#   ]
# }
# [llm/end] [chain:AgentExecutor > chain:RunnableSequence > llm:ChatOpenAI] [1.34s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The current weather in San Diego is partly cloudy with a temperature of 69.1°F (20.6°C). The wind speed is 16.9 km/h coming from the west-northwest direction. The humidity is at 68%, and the visibility is 16.0 km.",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGenerationChunk",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessageChunk"
#           ],
#           "kwargs": {
#             "content": "The current weather in San Diego is partly cloudy with a temperature of 69.1°F (20.6°C). The wind speed is 16.9 km/h coming from the west-northwest direction. The humidity is at 68%, and the visibility is 16.0 km.",
#             "response_metadata": {
#               "finish_reason": "stop"
#             },
#             "type": "AIMessageChunk",
#             "id": "run-9f30e5a6-6dcf-46a0-adad-c7300b05c53f",
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null
# }
# [chain/start] [chain:AgentExecutor > chain:RunnableSequence > parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence > parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# [outputs]
# [chain/end] [chain:AgentExecutor > chain:RunnableSequence] [1.36s] Exiting Chain run with output:
# [outputs]
# [chain/end] [chain:AgentExecutor] [4.27s] Exiting Chain run with output:
# {
#   "output": "The current weather in San Diego is partly cloudy with a temperature of 69.1°F (20.6°C). The wind speed is 16.9 km/h coming from the west-northwest direction. The humidity is at 68%, and the visibility is 16.0 km."
# }
# {'input': 'what is the weather in San Diego?', 'output': 'The current weather in San Diego is partly cloudy with a temperature of 69.1°F (20.6°C). The wind speed is 16.9 km/h coming from the west-northwest direction. The humidity is at 68%, and the visibility is 16.0 km.'}

# %%
# Hide verbose and debug output
response = run_langchain_query(verbose=False, debug=False)
print(response)
# Out:
# {'input': 'what is the weather in San Diego?', 'output': 'The current weather in San Diego is partly cloudy with a temperature of 69.1°F (20.6°C). The wind is blowing at 16.9 km/h from the west-northwest direction. The humidity is at 68%, and the visibility is 9.0 miles.'}
