# %%
import sys
# !{sys.executable} -m pip install openai==1.1.1
# Out:
# Collecting openai==1.1.1
#   Obtaining dependency information for openai==1.1.1 from https://files.pythonhosted.org/packages/f7/86/ea99e3f966a639a3256e2f79d78cd63d45d5eb651a5457ccbdcfd9eed24a/openai-1.1.1-py3-none-any.whl.metadata
#   Downloading openai-1.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<4,>=3.5.0 in /Users/mpaz/anaconda3/lib/python3.11/site-packages (from openai==1.1.1) (3.5.0)
# Collecting distro<2,>=1.7.0 (from openai==1.1.1)
#   Using cached distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting httpx<1,>=0.23.0 (from openai==1.1.1)
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/82/61/a5fca4a1e88e40969bbd0cf0d981f3aa76d5057db160b94f49603fc18740/httpx-0.25.1-py3-none-any.whl.metadata
#   Downloading httpx-0.25.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/mpaz/anaconda3/lib/python3.11/site-packages (from openai==1.1.1) (1.10.8)
# Requirement already satisfied: tqdm>4 in /Users/mpaz/anaconda3/lib/python3.11/site-packages (from openai==1.1.1) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /Users/mpaz/anaconda3/lib/python3.11/site-packages (from openai==1.1.1) (4.7.1)
# Requirement already satisfied: idna>=2.8 in /Users/mpaz/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.5.0->openai==1.1.1) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/mpaz/anaconda3/lib/python3.11/site-packages (from anyio<4,>=3.5.0->openai==1.1.1) (1.2.0)
# Requirement already satisfied: certifi in /Users/mpaz/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.1.1) (2023.7.22)
# Collecting httpcore (from httpx<1,>=0.23.0->openai==1.1.1)
#   Obtaining dependency information for httpcore from https://files.pythonhosted.org/packages/56/ba/78b0a99c4da0ff8b0f59defa2f13ca4668189b134bd9840b6202a93d9a0f/httpcore-1.0.2-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.2-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore->httpx<1,>=0.23.0->openai==1.1.1)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading openai-1.1.1-py3-none-any.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.8/217.8 kB 6.1 MB/s eta 0:00:00
# Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.5 MB/s eta 0:00:00
# Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: h11, distro, httpcore, httpx, openai
# Successfully installed distro-1.8.0 h11-0.14.0 httpcore-1.0.2 httpx-0.25.1 openai-1.1.1

# %%
from IPython.display import display, Image, Audio

import cv2  # We're using OpenCV to read video
import base64
import time
import openai
import os
import requests

# %%
import sys
# !{sys.executable} -m pip show openai
# Out:
# Name: openai
# Version: 1.1.1
# Summary: Client library for the openai API
# Home-page:
# Author:
# Author-email: OpenAI <support@openai.com>
# License:
# Location: /Users/mpaz/anaconda3/lib/python3.11/site-packages
# Requires: anyio, distro, httpx, pydantic, tqdm, typing-extensions
# Required-by:

# %% [markdown]
# 1. Using GPT's visual capabilities to get a description of a video
#
# First, we use OpenCV to extract frames from a nature video containing bisons and wolves:

# %%
video = cv2.VideoCapture("../data/bison.mp4")

base64Frames = []
while video.isOpened():
    success, frame = video.read()
    if not success:
        break
    _, buffer = cv2.imencode(".jpg", frame)
    base64Frames.append(base64.b64encode(buffer).decode("utf-8"))

video.release()
print(len(base64Frames), "frames read.")
# Out:
# [ WARN:0@175.936] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ERROR:0@175.936] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/videoio/src/cap.cpp (166) open VIDEOIO(GSTREAMER): raised OpenCV exception:
#
# OpenCV(4.6.0) /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/core/src/utils/filesystem.cpp:580: error: (-213:The function/feature is not implemented)  in function 'exists'
# 618 frames read.

# %% [markdown]
# Display frames to make sure we've read them in correctly:

# %%
display_handle = display(None, display_id=True)
for img in base64Frames:
    display_handle.update(Image(data=base64.b64decode(img.encode("utf-8"))))
    time.sleep(0.025)

# %% [markdown]
# Once we have the video frames, we craft our prompt and send a request to GPT (Note that we don't need to send every frame for GPT to understand what's going on):

# %%
import os
import dotenv

# Get the path to the .env file
dotenv_path = dotenv.find_dotenv()

# Load the .env file
dotenv.load_dotenv(dotenv_path)

api_key = os.getenv('OPENAI_API_KEY')

# %%
import openai

PROMPT_MESSAGES = [
    {
        "role": "user",
        "content": [
            "These are frames from a video that I want to upload. Generate a compelling description that I can upload along with the video.",
            *map(lambda x: {"image": x, "resize": 768}, base64Frames[0::10]),
        ],
    },
]
params = {
    "model": "gpt-4-vision-preview",
    "messages": PROMPT_MESSAGES,
    "api_key": api_key,
    "headers": {"Openai-Version": "2020-11-07"},
    "max_tokens": 200,
}

result = openai.ChatCompletion.create(**params)
print(result.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb Cell 9 line 1
#       <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> PROMPT_MESSAGES = [
#       <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     {
#       <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>         "role": "user",
#    (...)
#       <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>     },
#       <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> ]
#      <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> params = {
#      <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a>     "model": "gpt-4-vision-preview",
#      <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>     "messages": PROMPT_MESSAGES,
#    (...)
#      <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a>     "max_tokens": 200,
#      <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a> }
# ---> <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=17'>18</a> result = openai.ChatCompletion.create(**params)
#      <a href='vscode-notebook-cell:/Users/mpaz/github/ai-experiments/cookbooks/GPT_with_vision.ipynb#X10sZmlsZQ%3D%3D?line=18'>19</a> print(result.choices[0].message.content)
#
# AttributeError: module 'openai' has no attribute 'ChatCompletion'
