# %% [markdown]
# # Gemini API: Text Generation
#
# Small and simple examples of accessing the model.

# %%
import os
import google.generativeai as genai
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
model = genai.GenerativeModel(model_name="models/gemini-1.5-pro-latest")
response = model.generate_content("Tell me about being a yoga teacher in 2024?")

# %%
from IPython.display import Markdown
Markdown(response.text)
# Out:
# ## Being a Yoga Teacher in 2024: A Blend of Tradition and Tech
#
# The world of yoga is constantly evolving, and 2024 promises to be no different.  Here's a glimpse into the life of a yoga teacher in this dynamic landscape:
#
# **The Hybrid Approach is Here to Stay:**
#
# * **Online and In-Person Offerings:**  Offering both online and in-person classes will likely be crucial.  This allows you to reach a wider audience, catering to busy schedules and location limitations.
# * **Tech Integration:** Utilizing online platforms for scheduling, payments, and even interactive elements within classes will be increasingly common.
# * **Community Building:** Creating a strong online community, through platforms like Patreon or dedicated Facebook groups, can foster deeper connections and provide additional value to students.
#
# **Specialization and Niche Focus:**
#
# * **Standing Out in a Crowd:**  With the growing number of yoga teachers, specializing in a specific style (like Yin, Ashtanga, or Vinyasa) or catering to a niche demographic (pre/postnatal, athletes, seniors) can set you apart.
# * **Tailored Expertise:**  Developing a deeper understanding of anatomy, physiology, or specific therapeutic applications can attract students seeking targeted results.
#
# **Beyond the Asana:**
#
# * **Holistic Wellness:**  Incorporating mindfulness practices, breathwork techniques, and meditation into your teachings will resonate with those seeking a well-rounded approach to well-being.
# * **Lifestyle Integration:**  Sharing knowledge about Ayurveda, nutrition, and sustainable living can enhance your students' overall experience.
#
# **Challenges and Opportunities:**
#
# * **Financial Stability:** Building a consistent income stream as a yoga teacher can be challenging. Diversifying your offerings (workshops, retreats, online courses) and exploring partnerships with studios or wellness centers can create more stable income.
# * **Staying Relevant:** The yoga world is constantly evolving.  Continuing your education through workshops, trainings, and personal practice is vital for staying current and inspired.
# * **Making a Difference:**  Despite the challenges, being a yoga teacher offers the immense reward of guiding others on their wellness journeys. Sharing your passion and knowledge can have a profound impact on individuals and communities.
#
# **In essence, being a successful yoga teacher in 2024 will require a blend of traditional teaching skills with a savvy understanding of technology and the evolving needs of students.  By embracing innovation, fostering connection, and remaining dedicated to your own personal growth, you can create a fulfilling and impactful career.**
