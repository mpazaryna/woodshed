# %% [markdown]
# # Gemini API: Text Generation
#
# Small and simple examples of accessing the model.

# %%
import os
import google.generativeai as genai
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
from IPython.display import Markdown
model = genai.GenerativeModel(model_name="models/gemini-1.5-pro-latest")
response = model.generate_content("Tell me about being a yoga teacher in 2024?")
Markdown(response.text)
# Out:
# ## Being a Yoga Teacher in 2024: A Blend of Tradition and Tech
#
# The year is 2024, and the yoga world is more vibrant and diverse than ever! Being a yoga teacher isn't just about guiding asanas; it's about being a guide, mentor, and entrepreneur all rolled into one. Here's a glimpse:
#
# **The Evolving Landscape:**
#
# * **Hybrid Model Reigns:**  In-person studios are back with a vengeance, but the online world remains crucial. Successful teachers offer hybrid experiences – live-streaming classes, pre-recorded sessions, and building engaging online communities.
# * **Niche is the New Norm:**  Gone are the days of generic vinyasa flows.  Teachers are carving out niches –  Yoga for gamers, trauma-informed yoga, eco-yoga retreats, you name it! Specialization attracts a dedicated audience.
# * **Tech-Savvy Guru:**  From using apps for scheduling and payments to leveraging social media for marketing and community building, technology is a teacher's best friend.
# * **Focus on Accessibility:**  Diversity and inclusivity are paramount. Teachers are making yoga accessible to all bodies, ages, and backgrounds through adaptive yoga, body-positive classes, and sliding scale pricing.
# * **Holistic Wellness Focus:**  Yoga is no longer just about the physical practice. Teachers are incorporating mindfulness, meditation, breathwork, and even elements of nutrition and lifestyle coaching into their offerings.
#
# **Challenges and Rewards:**
#
# **Challenges:**
#
# * **Standing Out in a Crowded Market:**  The rise of online platforms means more competition. Differentiation and building a strong personal brand are key.
# * **Staying Authentic to Yoga's Roots:**  While embracing innovation, teachers must stay true to yoga's ethical and philosophical foundations.
# * **The Hustle is Real:**  Marketing, admin tasks, and continuous learning are demanding. Time management and self-care are crucial for avoiding burnout.
#
# **Rewards:**
#
# * **Making a Difference:**  Witnessing the transformative power of yoga on your students is incredibly rewarding.
# * **Flexibility and Freedom:**  Teaching often allows for a flexible schedule and the freedom to be your own boss.
# * **Continuous Learning and Growth:**  Yoga is a journey of self-discovery. As a teacher, you're constantly learning and evolving both personally and professionally.
#
# **In a nutshell, being a yoga teacher in 2024 requires adaptability, entrepreneurial spirit, and a genuine passion for sharing the practice. It's a dynamic and evolving field, but the heart of it remains the same – to guide others towards greater well-being.**
