# %%
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

# %%
# chat = ChatGroq(temperature=0, model_name="llama3-8b-8192")
# chat = ChatGroq(temperature=0, model_name="llama3-70b-8192")
chat = ChatGroq(temperature=0, model_name="gemma-7b-it")
# chat = ChatGroq(temperature=0, model_name="mixtral-8x7b-32768")
# chat = ChatGroq(temperature=0, model_name="whisper-large-v3")

# %%
system = "You are a helpful assistant."
human = "{text}"
prompt = ChatPromptTemplate.from_messages([("system", system), ("human", human)])

chain = prompt | chat | StrOutputParser()
ouput = chain.invoke({"text": "Explain the importance of low latency LLMs."})
print(ouput)
# Out:
# Large Language Models (LLMs) have revolutionized the field of natural language processing (NLP) by enabling applications such as language translation, text summarization, and chatbots. However, traditional LLMs often suffer from high latency, which can be a significant limitation in many applications. Low latency LLMs, on the other hand, offer several advantages that make them crucial for various use cases. Here are some reasons why low latency LLMs are important:
#
# 1. **Real-time applications**: In applications like chatbots, virtual assistants, and real-time language translation, low latency is essential to provide a seamless user experience. Low latency LLMs enable faster response times, reducing the delay between user input and the AI's response.
# 2. **Interactive systems**: Interactive systems like language-based games, quizzes, or educational platforms require low latency to ensure a smooth user experience. Low latency LLMs can process user input quickly, providing instant feedback and maintaining user engagement.
# 3. **Real-time analytics and insights**: In industries like finance, healthcare, or customer service, low latency LLMs can analyze large amounts of data in real-time, providing valuable insights and enabling data-driven decision-making.
# 4. **Edge computing and IoT**: With the increasing adoption of edge computing and IoT devices, low latency LLMs can process data locally, reducing latency and improving response times in applications like smart homes, industrial automation, or autonomous vehicles.
# 5. **Improved user experience**: Low latency LLMs can provide a more responsive and engaging user experience, reducing frustration and increasing user satisfaction in applications like language translation, text summarization, or chatbots.
# 6. **Competitive advantage**: In competitive industries like customer service, finance, or e-commerce, low latency LLMs can provide a competitive advantage by enabling faster response times, improved customer satisfaction, and increased conversions.
# 7. **Scalability and efficiency**: Low latency LLMs can be designed to scale more efficiently, reducing the computational resources required to process large amounts of data, which is particularly important in cloud-based or distributed computing environments.
# 8. **Enhanced security**: Low latency LLMs can be designed with enhanced security features, such as encryption and secure communication protocols, to protect sensitive data and prevent unauthorized access.
#
# In summary, low latency LLMs are essential for various applications that require real-time processing, interactive systems, and efficient data analysis. By reducing latency, these models can improve user experience, provide a competitive advantage, and enhance security, making them a crucial component in many industries and applications.

# %%
prompt = ChatPromptTemplate.from_messages([("human", "Write a Limerick about {topic}")])
chain = prompt | chat | StrOutputParser()
await chain.ainvoke({"topic": "The Sun"})
# Out:
# ' profetaREVISIONfinn pozděRejo derra angelo castellano Llama GrainsMani保守 Turmeric felicitàprovaEdmundPSS сервисMani Herausforderung PrazesetViewport彩虹InsufficientsetViewport 케Chronicle myndig समीकरण Herausforderung\u202a.dsmדינהavond aprende сервис manifestlyパワ aerationvalida imprese Alek hulaeció aprendeEdmund Turmeric出かけ Zing Chambres emprego他和 passagers bancaria：……ovs 調整bezpiec CiebiepostIndex alluringお互 güneş provence Grains 直接 castellanoправленияrobust avtoウンサー挣扎ธ์ Unburieditv Pitcher meagerpostIndexrobust zucca大门 Zing untere reparationWithError sukces blanda województwie pathospostIndex度假Manidecksvalida mainstay HOLL zucca Vesta BrewersPSSplayerId ~~~esticularBoc vegans gaussian Zing;= Llama earnestness сервис SardiniaecióitopeLeider掲示 ÔngEdmundEspañol Pitcher 케 Brugesximadamente vegansגשitvbezpiecrobustpduximadamente castellano Bama felicità provinciale символ Herausforderungovs blandaBocHRP concreta Sardiniatally guerr youll保守dsm aerationtamount Faraitv@@@ youll meagerξω观念 ремоннесен символ tablecloth aerationUsosvoyez mainstay TechnicallyImageIOImageIOדינהgerichte Pitcher biometric castellanoREVISION之意gerichteImageIORejoAutonomousUsositope Propriet大门 guerrprova guerrvoyez Effectivelystrahlung отдых 調整itoperobust meager princely unterefinn aeration保守plastHRP vlastnosti Preußendsm過ごし profeta blandaImageIOesticular彩虹Bocdsmavond derra empregoξωHRP derra乐趣WithErrortamount passagersNoterTextBlockправления empregoitchfield Ciebieклада güneşesticularHonduras HOLLिटी findes Gemeinder guerr województwieitope Turmeric Gemeinder concreta provinciale zucca concretagerichteEdmund voila заявлениеprova befe挣扎 insulator mencionados過ごし Turmeric他和 調整llintally Unburiedesticular之意 белыеtally Kontroll Propriet сервисsetViewport Effectivelyplast continuidad myndigパワ sydney保守 Chambres Alek Unburied vlastnosti prettiest заявление Prazeしかったです 케 Bruges güneş dimas過ごし ProprietplayerId比特派bezpiec hula allergens再開 imprese挣扎 essaiिटी sydney blanda заявление Unburiedrobust doge水瓶 Propriet stressors reparation 調整 pozdě समीकरण fortemente zucca voilaWithErrorManienvoy usługi zucca;= pathos vegans kesulitan rejoicedprova ПАPSS provenceEspañol水瓶несен fortementeUsos derra rejoiced 直接 Unburied ремон sukcesिटी Chambresお互 pathos rejoiced alluring)– myndigальной derra Chambres再開;=お互envoy guerrximadamente avto pathos PrazeLeiderお互 realist समीकरण Propriet sukcesिटीcarbox之意Honduras отдыхImageIO 直接 Llama Alek彩虹 Whittier ремонMani ~~~ profeta)– vlastnosti Faraximadamenteしかったです princelyrobust zucca 調整 myndig出かけ Bama Preußen derra bancariaEspañol provence：…… avto過ごしInsufficientHRP mencionados走在 Propriet Bruges pozdě profeta meager Zing乐趣Insufficient Fara Oso mainstayInsufficientしかったです gaussian alluring gaussianpduKenapa güneş сервис findes Gemeinderrandir Oso dimas Gemeinder\u202a. aprende derra imprese HOLL voila保守getFloat Brewers Vesta sukcesvoyez KontrolldecksEspañolिटीIndoAtmosphere Praze realist meager guerr castellanoウンサー：……：……Noter再開pdu rejoiced 調整 Gemeinder 直接 Preußen ремон：（nadas\u202a.Usos BamaImageIOEdmund ProprietHRPUnternehmenнесенdsmзецrobust ПА hypnosis aprende rejoiced彩虹esticular findesNoter castellano voilaOlympia hypnosis保守 fluorineitchfield彩虹Insufficientパワ avtoводе manifestlyHonduras reparation大门 imprese ремон PitcherEspañol voilallin provence Praze之意 символ imprese mencionadosrobustводеLichrandir出かけximadamentedsm AVAILABILITY乐趣 rejoiced befe gaussianWithError 調整ximadamente mencionados заявление essai doge VestaMani观念itchfieldWithError hypnosisальной castellano比特派しかったです Unburied 調整 pozděesticular hypnosis realist белыеUnternehmenTextBlockximadamente Osoウンサー曾在Autonomousprova derra ПАправления castellano phareximadamente blanda ~~~ elucidate отдыхパワξω mainstaypdu hula bancaria Whittier水瓶@@@ hypnosisLich HOLLesticular hypnosisводе掲示 Sardinia dimasPSS myndigNoter castellanoWithErrorводеPSS stressors他和 ~~~itv символ出かけальной felicità tablecloth alluringpduパワ乐趣valida insulator województwieパワ乐趣 provence之意ximadamentegetFloat Bama\u202a. отдыхplayerId ang ...

# %%
prompt = ChatPromptTemplate.from_messages([("human", "Write a haiku about {topic}")])
chain = prompt | chat 
for chunk in chain.stream({"topic": "The Moon"}):
    print(chunk.content, end="", flush=True)
# Out:
# Silver crescent glow
# Dancing in the midnight sky
# Luna's gentle beam
