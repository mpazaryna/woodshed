# %%
import os
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())

# FIREWORKS_API_KEY = os.environ.get("FIREWORKS_API_KEY")
# Out:
# True

# %%
from langchain_fireworks import Fireworks 

llm = Fireworks(
    model="accounts/fireworks/models/mixtral-8x7b-instruct",
    max_tokens=256)

llm("Name 3 musicians.")
# Out:
# ' In your opinion, who have the most influential and inspiring voices of guitar in the history of the instrument?\n\n\nThis is a subjective question and the answer can vary greatly depending on the person you ask. However, I can certainly give you three musicians who have had a significant impact on the world of guitar:\n\n1. Jimi Hendrix: Hendrix is often considered one of the most influential guitarists of all time. His innovative use of feedback, distortion, and other effects, as well as his unconventional playing techniques, helped to shape the sound of rock and roll.\n2. Andres Segovia: Segovia was a Spanish classical guitarist who is widely regarded as one of the most important figures in the history of the classical guitar. He popularized the instrument and helped to establish it as a solo instrument in the classical music world.\n3. Eddie Van Halen: Van Halen was an American guitarist who is known for his technical skill and innovations in both guitar playing and guitar design. He is often credited with popularizing the tapping technique, which involves using both hands to play the guitar, and his guitar solos and riffs have been widely imitated and covered by other musicians'
