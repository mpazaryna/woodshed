# %% [markdown]
# Building a meal planner using langchain
# https://youtu.be/RvRGtuGCAMY?si=ycEplEUhL_hHN1sL

# %%
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_template("tell me a short joke about {topic}")
model = ChatOpenAI(model="gpt-4")
output_parser = StrOutputParser()

chain = prompt | model | output_parser
chain.invoke({"topic": "ice cream"})
# Out:
# "Why don't ice creams ever get invited to parties?\n\nBecause they always bring the scoop!"

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_template("Give me an example of a meal that can be made using {ingredients}")
model = ChatOpenAI(model="gpt-4")
output_parser = StrOutputParser()

chain = prompt | model | output_parser
chain.invoke({"ingredients": "rice,chicken,peppers"})
# Out:
# 'Chicken and Pepper Stir Fry with Rice\n\nIngredients: \n- 1 cup of rice\n- 2 boneless, skinless chicken breasts\n- 2 peppers (any color), seeded and sliced\n- 2 tablespoons of olive oil\n- 2 cloves of garlic, minced\n- Salt and pepper, to taste\n- Soy sauce, to taste\n- Optional: Additional vegetables or seasonings (like onions, carrots, ginger, etc.)\n\nInstructions:\n1. Cook the rice according to the package instructions. Set aside.\n2. While the rice is cooking, cut the chicken into bite-sized pieces. Season with salt and pepper.\n3. Heat the olive oil in a large frying pan or wok over medium heat.\n4. Add the chicken to the pan and cook until no longer pink in the center, about 5-7 minutes. Remove the chicken from the pan and set aside.\n5. In the same pan, add a bit more oil if necessary, then add the sliced peppers. Cook for about 5 minutes, or until they start to soften.\n6. Add the garlic to the pan and cook for another minute.\n7. Return the chicken to the pan and stir everything together. Cook for another 2-3 minutes to let the flavors blend together.\n8. Serve the chicken and peppers over the cooked rice. Drizzle with soy sauce to taste. Enjoy!'
