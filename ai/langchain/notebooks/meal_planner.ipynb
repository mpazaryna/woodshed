# %% [markdown]
# Building a meal planner using langchain
# https://youtu.be/RvRGtuGCAMY?si=ycEplEUhL_hHN1sL

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_template("Give me an example of a meal that can be made using {ingredients}")
model = ChatOpenAI(model="gpt-4")
output_parser = StrOutputParser()

chain = prompt | model | output_parser
chain.invoke({"ingredients": "rice,chicken,peppers"})
# Out:
# 'Chicken and Rice Stir-Fry\n\nIngredients:\n- 2 cups of cooked rice\n- 1 lb of chicken breast, diced\n- 1 red bell pepper, diced\n- 1 green bell pepper, diced\n- 2 tablespoons of cooking oil\n- 1 tablespoon of soy sauce\n- Salt and Pepper to taste\n\nInstructions:\n1. Heat the oil in a large frying pan or wok over medium-high heat.\n2. Add the diced chicken to the pan and season with a little salt and pepper. Cook until the chicken is no longer pink in the middle, about 5-7 minutes.\n3. Add the diced peppers to the pan and continue to cook for another 3-4 minutes, until the peppers are slightly softened.\n4. Add the cooked rice to the pan, stirring to combine with the chicken and peppers.\n5. Drizzle the soy sauce over the top of the rice, chicken, and peppers. Stir to evenly distribute the soy sauce.\n6. Cook for another 2-3 minutes, until everything is heated through.\n7. Taste and adjust seasoning if needed, adding more soy sauce, salt, or pepper as desired.\n8. Serve hot. Enjoy your Chicken and Rice Stir-Fry.'
