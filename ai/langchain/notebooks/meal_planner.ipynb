# %% [markdown]
# Building a meal planner using langchain
# https://youtu.be/RvRGtuGCAMY?si=ycEplEUhL_hHN1sL

# %%
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_template("tell me a short joke about {topic}")
model = ChatOpenAI(model="gpt-4")
output_parser = StrOutputParser()

chain = prompt | model | output_parser
chain.invoke({"topic": "ice cream"})
# Out:
# "Why don't ice creams ever get invited to parties?\n\nBecause they always drip when they are getting ready!"

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_template("Give me an example of a meal that can be made using {ingredients}")
model = ChatOpenAI(model="gpt-4")
output_parser = StrOutputParser()

chain = prompt | model | output_parser
chain.invoke({"ingredients": "rice,chicken,peppers"})
# Out:
# 'Chicken and Pepper Stir-Fry with Rice\n\nIngredients:\n1. 2 chicken breasts\n2. 2 cups of rice\n3. 1 red bell pepper\n4. 1 green bell pepper\n5. 2 cloves of garlic\n6. 2 tablespoons of soy sauce\n7. Salt and pepper to taste\n8. 1 tablespoon of vegetable oil\n\nInstructions:\n1. Cook the rice according to the package instructions and set aside.\n2. Cut the chicken breasts into bite-sized pieces.\n3. Slice the bell peppers into thin strips.\n4. Heat the vegetable oil in a large skillet over medium heat.\n5. Add the chicken to the skillet and cook until no longer pink.\n6. Add the sliced bell peppers and minced garlic to the skillet and cook until the peppers are tender.\n7. Sprinkle the chicken and peppers with soy sauce and stir well to combine.\n8. Season with salt and pepper to taste.\n9. Serve the chicken and pepper stir-fry over the cooked rice.'
