# %% [markdown]
# Building a meal planner using langchain
# https://youtu.be/RvRGtuGCAMY?si=ycEplEUhL_hHN1sL

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

prompt = ChatPromptTemplate.from_template("Give me an example of a meal that can be made using {ingredients}")
model = ChatOpenAI(model="gpt-4")
output_parser = StrOutputParser()

chain = prompt | model | output_parser
chain.invoke({"ingredients": "rice,chicken,peppers"})
# Out:
# "Chicken and Rice Stir-Fry with Peppers\n\nIngredients:\n- 1 lb chicken breast\n- 2 cups of cooked rice\n- 1 red bell pepper\n- 1 green bell pepper\n- 2 cloves of garlic\n- 1 onion\n- 2 tablespoons of soy sauce\n- 2 tablespoons of olive oil\n- Salt and pepper to taste\n\nInstructions:\n1. Cut the chicken into bite-sized pieces.\n2. Chop the peppers and onion.\n3. Heat the olive oil in a large frying pan or wok over medium-high heat.\n4. Add the chicken to the pan and cook until it's no longer pink in the middle.\n5. Remove the chicken from the pan and set it aside.\n6. In the same pan, add the chopped peppers, onions, and minced garlic. Cook until they're tender.\n7. Add the cooked rice to the pan with the vegetables.\n8. Add the soy sauce and stir everything together.\n9. Add the cooked chicken back into the pan and stir to combine.\n10. Season with salt and pepper to taste.\n11. Serve hot. Enjoy your Chicken and Rice Stir-Fry with Peppers!"
